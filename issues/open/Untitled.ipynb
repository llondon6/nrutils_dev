# %%
# Checking of scbuild behavior

# %%
# Import usefuls 
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from nrutils import scbuild,simdir2scentry,gwylm,scsearch
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 
simdir = '/Users/book/MOUNT/tmp/mnt/hogshead/NR_data/ReducedData-hogshead/chinmay_precessingRuns/q2_a10_a27_ph90_th90/'
e = simdir2scentry(simdir,verbose=True)
# Out:
# # ---------------------------------------------------------------------------------------------- #
# (simdir2scentry)>> We will now try to convert a given directory to a scentry object.
# # ---------------------------------------------------------------------------------------------- #
#
#
# # ################################################################################################################################################################################################## #
# (simdir2scentry)>> (1) The directory must be compatible with a known config ini file. Let's load all known configs and use the first one which successfully parses the given directory.
# # ################################################################################################################################################################################################## #
#
#
# # ################################################################################ #
# ...

# %%
#
y = gwylm(e[0],lmax=2,verbose=True,clean=True)
# Out:
# (gwylm)>> Found clean (=True) keyword.
# (gwylm)>> Found dt (=0.15) keyword.
# (gwylm)>> Found lmax (=2) keyword.
# (gwylm)>> Found scentry_obj (=<nrutils.core.nrsc.scentry instance at 0x1c1f5df320>) keyword.
# (gwylm)>> Found verbose (=True) keyword.
# (__make_lmlist__)>> The following spherical multipoles will be loaded:[(2, -2), (2, -1), (2, 0), (2, 1), (2, 2)]
# (load)>> Loading: psi3col.r5.l5.l2.m-2.gz
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (15160, 3). Now the shape is (15163, 3).
# (load)>> Loading: psi3col.r5.l5.l2.m-1.gz
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (15160, 3). Now the shape is (15163, 3).
# (load)>> Loading: psi3col.r5.l5.l2.m0.gz
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (15160, 3). Now the shape is (15163, 3).
# (load)>> Loading: psi3col.r5.l5.l2.m1.gz
# (load)>> Imposing a default padding of 3 to the data.
# ...

# %%
y.plot(kind='strain')

# %%
y.mollweide_plot(form='abs')
# Out:
# (<matplotlib.axes._subplots.MollweideAxesSubplot at 0x1c1b7c9c90>,
#  1458.1499999999999)
