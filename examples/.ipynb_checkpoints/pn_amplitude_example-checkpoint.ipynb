# %% [markdown]
# # Example/Testing for Frequency Domain PN Amplitudes

# %%
# Setup ipython environment
# %load_ext autoreload
# %autoreload 2
# %matplotlib auto
# %matplotlib inline
# Import useful things
from kerr import rgb,gmvpfit,modelrd,anglep,qnmfit,leaver,ndflatten,sunwrap,magenta,alert,green,modelrd,mmrdnp
from nrutils import scsearch,gwylm,jf14067295,Mf14067295
from nrutils.core.nrsc import lswfafd
from nrutils.generate import pn
# Setup plotting backend
import matplotlib as mpl
from mpl_toolkits.mplot3d import axes3d
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size'] = 12
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['axes.titlesize'] = 20
from matplotlib.pyplot import *
from mpl_toolkits.mplot3d import Axes3D
#
from numpy import *
from numpy.linalg import pinv
#
from scipy.optimize import minimize
#
import pickle
import lalsimulation as lalsim
# Out:
# The highest level init for nrutils is located at: /Users/book/JOKI/Libs/KOALA/nrutils_dev/nrutils/__init__.pyc
#
# >> Initiating nrutils ...
#
# >> Sub-Packages to be imported:
#    -> core
#    -> formula
#    -> generate
#    -> manipulate
#    -> tools
# >> Please note style conventions:
#    * lower case function/method/variable names
#    * no underscore in names unless there are repeated letters, or counfounded syllables
#    * information is implicitely in time domain unless explicitely stated.
#    * frequency domain information will start with "fd".
#
# nrutils:
#
#   .core:
#       .basics*
#       .basics
#       .nrsc
#   .formula:
#   nrutils.formula: Found formula module "HPN050317"
#   .generate:
#   .manipulate:
#       .bundlers
#       .rotate
#   .tools:
#     .unit:
#       .conversion
#
# kerr## Found formula module "ksm2_cw"
# kerr## Found formula module "ksm2_sc"
# kerr## Found formula module "ksm2_slm_norm"
# kerr## Found formula module "mmrdnp_040317"
# kerr## Found formula module "mmrdnp_050217"
# kerr## Found formula module "mmrdnp_060217"
# kerr## Found formula module "mmrdnp_070217"
# kerr## Found formula module "mmrdnp_090117v2"
# kerr## Found formula module "mmrdnp_100117"
# kerr## Found formula module "mmrdnp_120217"
# kerr## Found formula module "mmrdnp_130217"
# kerr## Found formula module "mmrdnp_140217"
# kerr## Found formula module "mmrdnp_140217v2"
# kerr## Found formula module "mmrdnp_140217v3"
# kerr## Found formula module "mmrdnp_140217v4"
# kerr## Found formula module "mmrdnp_150217"
# kerr## Found formula module "mmrdnp_170117"
# kerr## Found formula module "mmrdnp_bam050217"
# kerr## Found formula module "mmrdns_amplitudes"
# kerr## Found formula module "mmrdns_Mfjf"

# %% [markdown]
# ## Load NR data and compare inpiral to PN code fr different modes

# %%
# Find Simulation
A = scsearch(q=2,institute='gt',verbose=True,unique=True)
# Out:
# [scsearch]>> Found institute (='gt') keyword.
# [scsearch]>> Found q (=2) keyword.
# [scsearch]>> Found unique (=True) keyword.
# [scsearch]>> Found validate_remnant (=False) keyword.
# [scsearch]>> Found verbose (=True) keyword.
# ## Found 15 unique simulations:
# [0001][bradwr] Sq-series: qc-1chi0.60-2chi0.60-p-q2.00	(Sq2_d6.2_a0.6_oth.270_rr_M140)
# [0002][bradwr] Sq-series: qc-1chi0.60-2chi0.60-p-q2.00	(Sq2_d6.2_a0.6_oth.180_rr_M140)
# [0003][bradwr] Sq-series: qc-1chi0.60-2chi0.60-p-q2.00	(Sq2_d6.2_a0.6_oth.150_rr_M140)
# [0004][bradwr] Sq-series: qc-1chi0.60-2chi0.60-p-q2.00	(Sq2_d6.2_a0.6_oth.090_rr_M140)
# [0005][bradwr] Sq-series: qc-1chi0.60-2chi0.60-p-q2.00	(Sq2_d6.2_a0.6_oth.030_rr_M140)
# [0006][bradwr] Sq-series: qc-1chi0.60-2chi0.60-p-q2.00	(Sq2_d6.2_a0.6_oth.000_rr_M140)
# [0007][bradwr] HR-series: 1chi0.40-2chi0.40-sa-q2.00	(D11_q2.00_a0.4_m160)
# [0008][bradwr] HR-series: 1chi0.20-2chi0.20-sa-q2.00	(D11_q2.00_a0.2_m160)
# [0009][bradwr] HR-series: ns-q2.00	(D11_q2.00_a0.0_m180)
# [0010][bradwr] HR-series: 1chi0.60-2chi0.60-saa-q2.00	(D11_q2.00_a-0.6_m200)
# [0011][bradwr] HR-series: 1chi0.40-2chi0.40-saa-q2.00	(D11_q2.00_a-0.4_m200)
# [0012][bradwr] HR-series: 1chi0.20-2chi0.20-saa-q2.00	(D11_q2.00_a-0.2_m200)
# [0013][bradwr] HR-series: 1chi0.30-sa-q2.00	(D12_q2.00_a0.30_0.00_m120)
# [0014][bradwr] HR-series: 1chi0.60-2chi0.60-sa-q2.00	(D11_q2.00_a0.60_m080)
# [0015][bradwr] HR-series: 1chi0.15-2chi0.60-p-q2.00	(D12_q2.00_a0.15_-0.60_m120)

# %%
# Select desired simulation
a = A[-1]

# %%
# Load waveform data
lmlist = [ (2,2), (2,1), (3,3), (3,2), (4,4), (4,3) ]
y = gwylm( a, lm=lmlist, verbose=True, clean=True )
# Out:
# (gwylm)>> Found clean (=True) keyword.
# (gwylm)>> Found lm (=[(2, 2), (2, 1), (3, 3), (3, 2), (4, 4), (4, 3)]) keyword.
# (gwylm)>> Found scentry_obj (=<nrutils.core.nrsc.scentry instance at 0x10a74c4d0>) keyword.
# (gwylm)>> Found verbose (=True) keyword.
# (gwylm)>> The (extraction_parameter,level) is (75.0,None), which differs from the config values of (75,0). You have either manually input the non-config values, or the handler has set them by looking at the contents of the simulation directory.
# (__make_lmlist__)>> The following spherical multipoles will be loaded:[(2, 2), (2, 1), (3, 3), (3, 2), (4, 4), (4, 3)]
# (load)>> Loading: Ylm_WEYLSCAL4::Psi4r_l2_m2_r75.00.asc
# (load)>> Loading: Ylm_WEYLSCAL4::Psi4r_l2_m1_r75.00.asc
# (load)>> Loading: Ylm_WEYLSCAL4::Psi4r_l3_m3_r75.00.asc
# (load)>> Loading: Ylm_WEYLSCAL4::Psi4r_l3_m2_r75.00.asc
# (load)>> Loading: Ylm_WEYLSCAL4::Psi4r_l4_m4_r75.00.asc
# (load)>> Loading: Ylm_WEYLSCAL4::Psi4r_l4_m3_r75.00.asc
# (gwylm)>> Storing w22 from a PN estimate[see pnw0 in basics.py, and/or arxiv:1310.1528v4]. This will be the frequency parameter used if strain is to be calculated.
# (calcflm)>> w0(w22) = 0.038973 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.019486 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.058459 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.038973 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.077945 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.058459 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calchlm)>> w0(w22) = 0.038973 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_pluss-1j*h_cross when appropriate.
# (calchlm)>> w0(w22) = 0.019486 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_pluss-1j*h_cross when appropriate.
# (calchlm)>> w0(w22) = 0.058459 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_pluss-1j*h_cross when appropriate.
# (calchlm)>> w0(w22) = 0.038973 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_pluss-1j*h_cross when appropriate.
# (calchlm)>> w0(w22) = 0.077945 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_pluss-1j*h_cross when appropriate.
# (calchlm)>> w0(w22) = 0.058459 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_pluss-1j*h_cross when appropriate.

# %% [markdown]
# ## Compare PN amplitude to NR amplitde for a select multipole

# %%
# select multipole l and m
mode = (2,2)
# Plot frequency domain waveform data
ax,fig = y.lm[mode]['strain'].plot(domain='freq')
# Add the PN amplitude to the plot 
f = y.lm[mode]['strain'].f; f = f[ f>0 ]
hfpn_amp = pn.hf_amp_np( f, y.eta, y.X1[-1], y.X2[-1], mode )
ax[0].plot( f, hfpn_amp, '--r', label='PN Amplitude' )
ax[0].legend(frameon=False)

# %% [markdown]
# ## Comapre PN with NR for all Loaded multipoles

# %%
# Add the PN amplitude to the plot 
pn_alm = {}
for mode in y.lm:
    f = y.lm[mode]['strain'].f; f = f[ f>0 ]
    pn_alm[mode] = pn.hf_amp_np( f, y.eta, y.X1[-1], y.X2[-1], mode )

# %%
fig = figure( figsize = 1.68*array([5,5]) )
clr = rgb( len(y.lm), reverse=True,  )
for k,mode in enumerate(y.lm):
    hlm = y.lm[mode]['strain']
    f = hlm.f; mask = f>0
    plot( f[mask], hlm.fd_amp[mask], color=clr[k], linewidth=1, label='(%i,%i)'%mode  )
    plot( f[mask], pn_alm[mode], color=0.99*clr[k], linestyle='--', linewidth=1)
#
xscale('log'); yscale('log')
xlim( [y.wstart/(4*pi),0.3] )
ylim( [1e-4,1e3] )
xlabel('$Mf$')
ylabel(r'$\frac{r}{M}h(f)$')
legend(frameon=False)
title('%s: Some aren\'t long enough'%y.label)
# savefig('pn_amplitude_example.png')
