# %% [markdown]
# # Make gwylm class understand directory and scentry as 1st input

# %%
# Setup ipython environment
# %load_ext autoreload
# %autoreload 2
# %matplotlib auto
# %matplotlib inline
# Import useful things
#
# from os import system
# system('source ~/.virtual_enviroments/ringdownFD_nikhef/bin/activate')
from nrutils import scsearch,gwylm,FinalSpin0815,EradRational0815,simdir2scentry
# Setup plotting backend
import matplotlib as mpl
from mpl_toolkits.mplot3d import axes3d
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size'] = 12
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['axes.titlesize'] = 20
from matplotlib.pyplot import *
from mpl_toolkits.mplot3d import Axes3D
#
import corner
#
from numpy import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Define a low-level package function to convert a directory into a list of simulation catalog objects

# %%
sim_dir = '/Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/'
sce = simdir2scentry( sim_dir, verbose=False )
# Out:
# (bam.py!)>> Warning: The afterjunk spins appear to have been stored incorrectly. All parameters according to the initial data (as stored in the bbh files) will be stored.

# %% [markdown]
# ### Print the properties of the "on-the-fly" catalog entry

# %%
a = sce[0]
for k in a.__dict__:
    print '%s \t = \t %s'%(k,a.__dict__[k])
# Out:
# metadata_file_location 	 = 	 /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.bbh
# verbose 	 = 	 False
# S2 	 = 	 [0 0 0]
# S1 	 = 	 [0 0 0]
# xf 	 = 	 0.44679399666
# static 	 = 	 True
# source_dir 	 = 	 []
# overwrite 	 = 	 False
# log 	 = 	 [Log for <nrutils.core.nrsc.scentry instance at 0x1095a6098>] The file is "/Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.bbh". This entry's metadata file is valid.
# isafterjunk 	 = 	 False
# label 	 = 	 ns-q4.00
# note 	 = 	 Warning: The afterjunk spins appear to have been stored incorrectly. All parameters according to the initial data (as stored in the bbh files) will be stored.
# __irrMf__ 	 = 	 0.977936312783
# valid 	 = 	 True
# m1 	 = 	 0.799997
# m2 	 = 	 0.200003
# X2 	 = 	 [ 0.  0.  0.]
# X1 	 = 	 [ 0.  0.  0.]
# config 	 = 	 <nrutils.core.nrsc.scconfig instance at 0x109202878>
# P2 	 = 	 [-0.0570992  -0.00028289  0.        ]
# P1 	 = 	 [ 0.0570992   0.00028289  0.        ]
# extraction_map_dict 	 = 	 {'level_map': {1: 6, 2: 6, 3: 6, 4: 6, 5: 6, 6: 6}, 'radius_map': {1: 50.0, 2: 60.0, 3: 70.0, 4: 80.0, 5: 90.0, 6: 100.0}}
# R1 	 = 	 [ 0.      -2.24658  0.     ]
# R2 	 = 	 [ 0.       8.98632  0.     ]
# default_extraction_par 	 = 	 5
# source_file_path 	 = 	 []
# mf 	 = 	 1.00476055824
# L2 	 = 	 [ 0.         -0.          0.51311168]
# L1 	 = 	 [-0.          0.          0.12827792]
# simname 	 = 	 q4a0_T_112_448
# Sf 	 = 	 [  2.97457100e-19   1.41981300e-18   4.51058100e-01]
# relative_simdir 	 =
# default_level 	 = 	 6
# b 	 = 	 11.2329
# setname 	 = 	 non-catalog
# isvalid 	 = 	 True
# madm 	 = 	 0.994066
# Xf 	 = 	 [  2.94645072e-19   1.40639072e-18   4.46793997e-01]
# raw_metadata 	 = 	 <positive.io.smart_object instance at 0x109202d88>
# eta 	 = 	 0.160001799991
# date_number 	 = 	 1501116409.0

# %% [markdown]
# ### Use the same directory as above to create a gwylm object outside of a pre-built catalog file
# NOTE: You will likely want to turn verbose off unless there's an issue.

# %%
y = gwylm(sim_dir,lmax=3,verbose=True,clean=True,dt=0.5)
# Out:
# (gwylm)>> Found clean (=True) keyword.
# (gwylm)>> Found dt (=0.5) keyword.
# (gwylm)>> Found lmax (=3) keyword.
# (gwylm)>> Found scentry_obj (='/Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/') keyword.
# (gwylm)>> Found verbose (=True) keyword.
# (gwylm!)>> You have input a directory rather than an scentry object. We will try to convert the directory to an scentry object, but this is slower than using the our catalog system. Please consider modifying the appropriate configuretion file (i.e. in "/Users/book/JOKI/Libs/KOALA/nrutils_dev/nrutils/config/") to occomodate your new simulation, or perhaps create a new configuration file. Given your new or updated configuration file, please run nrutils.scbuild("my_config_name") to update your local catalog. If you are confident that all has gone well, you may also wish to push changes in your catalog (to the master repo). Live long and prosper. -- Lionel
#
# # ---------------------------------------------------------------------------------------------- #
# (simdir2scentry)>> We will now try to convert a given directory to a scentry object.
# # ---------------------------------------------------------------------------------------------- #
#
#
# # ################################################################################################################################################################################################## #
# (simdir2scentry)>> (1) The directory must be compatible with a known config ini file. Let's load all known configs and use the first one which successfully parses the given directory.
# # ################################################################################################################################################################################################## #
#
# (validate!)>> Multiple catalog directories found. We will scan through the related list, and then store first the catalog_dir that the OS can find.
# (validate!)>> Selecting "/Volumes/athena/bradwr/"
# (validate!)>> Multiple catalog directories found. We will scan through the related list, and then store first the catalog_dir that the OS can find.
# (validate!)>> Selecting "/Users/book/MOUNT/tmp/mnt/hogshead/NR_data/ReducedData-hogshead/"
# (validate!)>> Multiple catalog directories found. We will scan through the related list, and then store first the catalog_dir that the OS can find.
# (validate!)>> Selecting "/Volumes/athena/silures/"
#
# # ################################################################################ #
# (simdir2scentry)>> (2) For all configs, try to build a catalog object.
# # ################################################################################ #
#
#
# # -~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~ #
# (simdir2scentry)>> Searching for .par in /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/. This may take a long time if the folder being searched is mounted from a remote drive.
# # -~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~ #
#
# (rfind)>> Seaching for .par in /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/:
#   ->  /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.par
# (simdir2scentry)>> done.
# (maya.validate!)>> waveform data could not be found.
# ## The following is invalid: /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.par
# [Log for <nrutils.core.nrsc.scentry instance at 0x1090d18c0>] The file is "/Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.par". This entry's metadta file is invalid.
#
# # -~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~ #
# (simdir2scentry)>> Searching for .bbh in /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/. This may take a long time if the folder being searched is mounted from a remote drive.
# # -~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~ #
#
# (rfind)>> Seaching for .bbh in /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/:
#   ->  /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/psi4modes.bbh
#   ->  /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.bbh
#   ->  /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.raw.bbh
# (simdir2scentry)>> done.
# ## The following is invalid: /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/psi4modes.bbh
# [Log for <nrutils.core.nrsc.scentry instance at 0x10c7397e8>] The file is "/Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/psi4modes.bbh". This entry's metadta file is invalid.
# ## Working: /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.bbh
# (bam.py!)>> Warning: The afterjunk spins appear to have been stored incorrectly. All parameters according to the initial data (as stored in the bbh files) will be stored.
# (scentry.learn_metadata)>> The handler is found to have a "infer_default_level_and_extraction_parameter" method. Rather than the config file, this method will be used to determine the default extraction parameter and level.
# ## The following is invalid: /Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.raw.bbh
# [Log for <nrutils.core.nrsc.scentry instance at 0x10c739878>] The file is "/Volumes/athena/silures/BAM/q4Sebastian/q4a0_T_112_448/q4a0_T_112_448/q4a0_T_112_448.raw.bbh". This entry's metadta file is invalid.
#
# # ###################################################################################################################### #
# (simdir2scentry)>> (3) The previous config was able to parse the given directory --- We're all done here! :D
# # ###################################################################################################################### #
#
# (gwylm)>> The (extraction_parameter,level) is (5,6), which differs from the config values of (5,5). You have either manually input the non-config values, or the handler has set them by looking at the contents of the simulation directory.
# (__make_lmlist__)>> The following spherical multipoles will be loaded:[(2, -2), (2, -1), (2, 0), (2, 1), (2, 2), (3, -3), (3, -2), (3, -1), (3, 0), (3, 1), (3, 2), (3, 3)]
# (load)>> Loading: psi3col.r5.l6.l2.m-2.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l2.m-1.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l2.m0.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l2.m1.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l2.m2.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l3.m-3.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l3.m-2.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l3.m-1.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l3.m0.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l3.m1.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l3.m2.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (load)>> Loading: psi3col.r5.l6.l3.m3.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (4702, 3). Now the shape is (4705, 3).
# (gwylm)>> Storing w22 from a PN estimate[see pnw0 in basics.py, and/or arxiv:1310.1528v4]. This will be the frequency parameter used if strain is to be calculated.
# (calcflm)>> w0(w22) = -0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = -0.021269 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.021269 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = -0.063808 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = -0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = -0.021269 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.021269 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.063808 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calchlm)>> w2-2 = m*w22/2 = -0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w2-1 = m*w22/2 = -0.021269 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w20 = m*w22/2 = 0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w21 = m*w22/2 = 0.021269 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w22 = m*w22/2 = 0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w3-3 = m*w22/2 = -0.063808 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w3-2 = m*w22/2 = -0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w3-1 = m*w22/2 = -0.021269 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w30 = m*w22/2 = 0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w31 = m*w22/2 = 0.021269 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w32 = m*w22/2 = 0.042539 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w33 = m*w22/2 = 0.063808 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.

# %% [markdown]
# ### Plot some of the loaded waveform data

# %%
for l,m in y.lm:
    if l==m: y.lm[l,m]['psi4'].plot()

# %%
y.mollweide_plot(form='abs')
# Out:
# (<matplotlib.axes._subplots.MollweideAxesSubplot at 0x11c280410>, 2193.0)
