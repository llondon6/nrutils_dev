# %% [markdown]
# # Core example for nrutils: Find a simulation, load and plot waveform data

# %% [markdown]
# ## Let's start by importing nrutils

# %%
# Setup enviroment to autoreload packages
# %load_ext autoreload
# %autoreload 2
# Turn on inline plotting with matplotlib, and import needed thigs from nrutils
# %matplotlib inline
# Let's only import the catalog search function, and the loading function
from nrutils import scsearch,gwylm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Find a simulation(s) using scsearch

# %%
# Search for simulations
A = scsearch(keyword='q2_85',verbose=True)
# Out:
# (scsearch)>> Found keyword (='q2_85') keyword.
# (scsearch)>> Found verbose (=True) keyword.
# (scsearch)>> List of keywords or string keyword found: ALL scentry objects matching will be passed. To pass ANY entries matching the keywords, input the keywords using an iterable of not of type list.
# ## Found 2 possibly degenerate simulations:
# [0001][silures] BAM: 2chi0.85-sa-q2.00	(q2_85_0_0.283333_T_80_400)
# [0002][silures] BAM: 1chi0.85-2chi0.85-p-q2.00	(q2_85_-85_-0.283333_T_80_440)

# %% [markdown]
# ## Loading the desired multipoles -- A single multipole

# %%
# Convert a single simulation into a waveform object with desired multipoles
y = gwylm( scentry_obj = A[0], lm=([2,2],[2,1]), verbose=True )
# Out:
# (gwylm)>> Found dt (=0.15) keyword.
# (gwylm)>> Found lm (=([2, 2], [2, 1])) keyword.
# (gwylm)>> Found scentry_obj (=<nrutils.core.nrsc.scentry instance at 0x1067495f0>) keyword.
# (gwylm)>> Found verbose (=True) keyword.
# (gwylm)>> The (extraction_parameter,level) is (2,6), which differs from the config values of (5,5). You have either manually input the non-config values, or the handler has set them by looking at the contents of the simulation directory.
# (__make_lmlist__)>> The following spherical multipoles will be loaded:[(2, 2), (2, 1)]
# (load)>> Loading: psi3col.r2.l6.l2.m2.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (15244, 3). Now the shape is (15247, 3).
# (load)>> Loading: psi3col.r2.l6.l2.m1.gz
# (straighten_wfarr!)>> The time series has been found to be non-monotonic. We will sort the data to enforce monotinicity.
# (straighten_wfarr!)>> The waveform time series is now monotonic.
# (straighten_wfarr!)>> Repeated time values were found in the array. Offending rows will be removed.
# (load)>> Imposing a default padding of 3 to the data.
# (pad_wfarr)>> The shape was (15244, 3). Now the shape is (15247, 3).
# (gwylm)>> Storing w22 from a PN estimate[see pnw0 in basics.py, and/or arxiv:1310.1528v4]. This will be the frequency parameter used if strain is to be calculated.
# (calcflm)>> w0(w22) = 0.043117 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calcflm)>> w0(w22) = 0.021559 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (calchlm)>> w22 = m*w22/2 = 0.043117 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.
# (calchlm)>> w21 = m*w22/2 = 0.021559 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_plus-1j*h_cross when appropriate.

# %% [markdown]
# ## Plot time domain strain. NOTE that strain is calculated automatically

# %%
# plot time domain strain
y.plot()
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x10c07e650>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10c17d0d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1083e3650>]

# %%
# plot time domain psi4
y.plot(kind='psi4',show=True,domain='time')
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x10d6304d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10c3381d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1085d62d0>]

# %%
# plot frequency domain psi4
y.plot(kind='psi4',show=True,domain='freq')
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x10c2feb50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1029edc50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10d5ae790>]

# %%
# plot frequency domain strain
y.plot(kind='strain',show=True,domain='freq')
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x106768d50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x108497110>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10b4fbf90>]
